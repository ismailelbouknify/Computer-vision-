# %%
# %config Completer.use_jedi = False
import pandas as pd
import numpy as np
import seaborn as sb
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

np.random.seed(11)
import warnings
warnings.filterwarnings('ignore')

from pandas import DataFrame
from sklearn.tree import plot_tree

import keras
import tensorflow as tf
from PIL import Image
import cv2

from tqdm import tqdm
from random import shuffle 

import os
import random as rn
from sklearn.preprocessing import LabelEncoder
from keras.utils.np_utils import to_categorical 

# specifically for cnn
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout, Flatten,Activation
from keras.layers import Conv2D, Conv1D, MaxPooling2D, BatchNormalization,MaxPool1D,MaxPool2D

#preprocess.
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping

from keras.optimizer_v1 import adam

# %% [markdown]
# # **chargement des images**

# %%
X=[] #contient les images
Z=[] #contient les labels pour chaque image
IMG_SIZE=224  #taille de l'image
#chemins des images pour chaque classe
DIR0=r'C:\Users\hp\BDSaS\Multimidia_Mining\Projet\voc\automobile' 
DIR1=r'C:\Users\hp\BDSaS\Multimidia_Mining\Projet\voc\plane'
DIR2=r'C:\Users\hp\BDSaS\Multimidia_Mining\Projet\voc\train'

# %%
#associer un label a chaque image
def assign_label(img,DIR_type):
    return DIR_type

# %%
#chargement des images dans la liste X 
def make_train_data(DIR_type,DIR):
  
    for img in tqdm(os.listdir(DIR)):
        label=assign_label(img,DIR_type)
        path = os.path.join(DIR,img)
        img = cv2.imread(path,cv2.IMREAD_COLOR)
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))
        X.append(np.array(img))
        Z.append(str(label))

# %%
make_train_data("automobile",DIR0)
print(len(X))
# Out:
# 100%|██████████| 81/81 [00:00<00:00, 169.11it/s]
# 81

# %%
make_train_data("plane",DIR1)
print(len(X))
# Out:
# 100%|██████████| 80/80 [00:00<00:00, 216.09it/s]
# 161

# %%
make_train_data("train",DIR2)
print(len(X))
# Out:
# 100%|██████████| 80/80 [00:00<00:00, 184.35it/s]
# 241

# %% [markdown]
# # **Visualisation**

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=rn.randint(0,len(Z))
        ax[i,j].imshow(X[l])
        ax[i,j].set_title('classe: '+Z[l])
        
plt.tight_layout()

# %% [markdown]
# # **Label Encoding**

# %%
#encoder les labels par exemple une image qui un label train ==> le label sera encoder comme suit [0,0,1] ['automobile','plane','train']
le=LabelEncoder()
Y=le.fit_transform(Z)
Y=to_categorical(Y,3) #convertir les images en un array de pixels 
X=np.array(X)
X=X/255 #standardiser les images

# %%
print(Z[90])
plt.imshow(X[90])
print(Y[90])
# Out:
# plane
# [0. 1. 0.]

# %% [markdown]
# # **Construction et entraînement du modèle**

# %%
#split data (train and test)
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.05,random_state=42)

# %%
np.random.seed(42)
rn.seed(42)

# %%
# # modelling starts using a CNN.

m = Sequential()

m.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',activation ='relu', input_shape = (IMG_SIZE, IMG_SIZE, 3)))
m.add(MaxPooling2D(pool_size=(2,2)))

m.add(Conv2D(filters =32, kernel_size = (3,3),padding = 'Same',activation ='relu'))
m.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

m.add(Conv2D(filters =64, kernel_size = (3,3),padding = 'Same',activation ='relu'))
m.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
m.add(Dropout(0.5))

m.add(Conv2D(filters =64, kernel_size = (3,3),padding = 'Same',activation ='relu'))
m.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))


m.add(Flatten())
m.add(Dense(units = 512, activation='relu'))
m.add(Dense(3, activation = "softmax"))

# %%
# compiler le modèle m avec obtimizer = adam et loss=categorical_crossentropy
m.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
m.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 224, 224, 32)      2432
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 112, 112, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 112, 112, 32)      9248
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 56, 56, 64)        18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               6423040
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 6,491,683
# Trainable params: 6,491,683
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model
history=m.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=30, batch_size=32)
# Out:
# Epoch 1/30
# 8/8 [==============================] - 5s 550ms/step - loss: 1.7620 - accuracy: 0.3158 - val_loss: 1.1002 - val_accuracy: 0.0769
# Epoch 2/30
# 8/8 [==============================] - 4s 488ms/step - loss: 1.0903 - accuracy: 0.3596 - val_loss: 1.1082 - val_accuracy: 0.0769
# Epoch 3/30
# 8/8 [==============================] - 4s 483ms/step - loss: 1.0523 - accuracy: 0.4035 - val_loss: 1.0888 - val_accuracy: 0.2308
# Epoch 4/30
# 8/8 [==============================] - 4s 488ms/step - loss: 0.9342 - accuracy: 0.5439 - val_loss: 0.8887 - val_accuracy: 0.6923
# Epoch 5/30
# 8/8 [==============================] - 4s 503ms/step - loss: 0.7779 - accuracy: 0.6360 - val_loss: 0.7142 - val_accuracy: 0.6923
# Epoch 6/30
# 8/8 [==============================] - 4s 511ms/step - loss: 0.6248 - accuracy: 0.7368 - val_loss: 0.6363 - val_accuracy: 0.7692
# Epoch 7/30
# 8/8 [==============================] - 4s 540ms/step - loss: 0.5673 - accuracy: 0.7675 - val_loss: 0.5995 - val_accuracy: 0.7692
# Epoch 8/30
# 8/8 [==============================] - 4s 506ms/step - loss: 0.4810 - accuracy: 0.7895 - val_loss: 0.6448 - val_accuracy: 0.7692
# Epoch 9/30
# 8/8 [==============================] - 4s 502ms/step - loss: 0.4898 - accuracy: 0.7895 - val_loss: 0.4982 - val_accuracy: 0.8462
# Epoch 10/30
# 8/8 [==============================] - 4s 489ms/step - loss: 0.4112 - accuracy: 0.8289 - val_loss: 0.4662 - val_accuracy: 0.8462
# Epoch 11/30
# 8/8 [==============================] - 4s 487ms/step - loss: 0.3362 - accuracy: 0.8684 - val_loss: 0.5190 - val_accuracy: 0.8462
# Epoch 12/30
# 8/8 [==============================] - 4s 462ms/step - loss: 0.3352 - accuracy: 0.8684 - val_loss: 0.4427 - val_accuracy: 0.7692
# Epoch 13/30
# 8/8 [==============================] - 4s 468ms/step - loss: 0.2467 - accuracy: 0.9079 - val_loss: 0.3310 - val_accuracy: 0.8462
# Epoch 14/30
# 8/8 [==============================] - 4s 482ms/step - loss: 0.2476 - accuracy: 0.8991 - val_loss: 0.3224 - val_accuracy: 0.8462
# Epoch 15/30
# 8/8 [==============================] - 4s 494ms/step - loss: 0.2708 - accuracy: 0.8816 - val_loss: 0.3615 - val_accuracy: 0.7692
# Epoch 16/30
# 8/8 [==============================] - 4s 479ms/step - loss: 0.4385 - accuracy: 0.8465 - val_loss: 0.4271 - val_accuracy: 0.8462
# Epoch 17/30
# 8/8 [==============================] - 4s 503ms/step - loss: 0.2610 - accuracy: 0.9254 - val_loss: 0.3814 - val_accuracy: 0.8462
# Epoch 18/30
# 8/8 [==============================] - 4s 492ms/step - loss: 0.2108 - accuracy: 0.9123 - val_loss: 0.3550 - val_accuracy: 0.8462
# Epoch 19/30
# 8/8 [==============================] - 4s 494ms/step - loss: 0.2182 - accuracy: 0.9123 - val_loss: 0.4454 - val_accuracy: 0.8462
# Epoch 20/30
# 8/8 [==============================] - 4s 543ms/step - loss: 0.1303 - accuracy: 0.9693 - val_loss: 0.4302 - val_accuracy: 0.8462
# Epoch 21/30
# 8/8 [==============================] - 4s 555ms/step - loss: 0.0928 - accuracy: 0.9781 - val_loss: 0.4569 - val_accuracy: 0.9231
# Epoch 22/30
# 8/8 [==============================] - 4s 508ms/step - loss: 0.0775 - accuracy: 0.9737 - val_loss: 0.2532 - val_accuracy: 0.9231
# Epoch 23/30
# 8/8 [==============================] - 4s 473ms/step - loss: 0.0499 - accuracy: 1.0000 - val_loss: 0.3146 - val_accuracy: 0.9231
# Epoch 24/30
# 8/8 [==============================] - 4s 497ms/step - loss: 0.1454 - accuracy: 0.9474 - val_loss: 0.2533 - val_accuracy: 0.9231
# Epoch 25/30
# 8/8 [==============================] - 4s 520ms/step - loss: 0.0950 - accuracy: 0.9605 - val_loss: 0.7128 - val_accuracy: 0.7692
# Epoch 26/30
# 8/8 [==============================] - 4s 500ms/step - loss: 0.0701 - accuracy: 0.9868 - val_loss: 0.3969 - val_accuracy: 0.8462
# Epoch 27/30
# 8/8 [==============================] - 4s 451ms/step - loss: 0.1039 - accuracy: 0.9561 - val_loss: 0.4494 - val_accuracy: 0.8462
# Epoch 28/30
# 8/8 [==============================] - 4s 481ms/step - loss: 0.0431 - accuracy: 0.9825 - val_loss: 0.5983 - val_accuracy: 0.8462
# Epoch 29/30
# 8/8 [==============================] - 4s 513ms/step - loss: 0.0815 - accuracy: 0.9649 - val_loss: 0.5655 - val_accuracy: 0.8462
# Epoch 30/30
# 8/8 [==============================] - 4s 484ms/step - loss: 0.0558 - accuracy: 0.9868 - val_loss: 0.6181 - val_accuracy: 0.8462

# %% [markdown]
# # **Evaluation sur les données de test**

# %%
m.evaluate(x_test,y_test)
# Out:
# 1/1 [==============================] - 0s 71ms/step - loss: 0.6181 - accuracy: 0.8462
# [0.6181386113166809, 0.8461538553237915]

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# # **Prédiction**

# %%
#cette fonction affiche les vraies classes et les classes prédites pour chaque image 
def evaluate_prediction(i):
  labels = ["automobile","plane","train"]
  if i in range(0,len(y_test)):
    pred=m.predict(x_test[i].reshape(-1,224,224,3))
    pred_arg=np.argmax(pred)
    plt.imshow(x_test[i])
    plt.title("Predicted class : "+labels[pred_arg]+"\n"+
          "Actual class : "+labels[np.argmax(y_test[i])])
  else :
    print("out of range of test data !!!")

# %%
evaluate_prediction(2)
